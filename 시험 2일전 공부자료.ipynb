# %%
#라이브러리 임포트
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#데이터 불러오기
df = pd.read_csv('_.csv')
df = pd.read_json('_.json')

#데이터 탐색하기
df.head()
df.tail()
df.info()
df.describe()
df.index
df.columns
df.values

#결측치 확인하기 #둘다 같은 기능이다. 결측값(null, nan)
df.isna().sum()
df.isnull().sum()

#특정 열의 값들의 건수/비율 확인하가ㅣ
df['a'].value_counts()
df['b'].value_counts(normalize=True)

#특정 열 삭제
cols=['A', 'B', 'C', 'D']
df = df.drop(cols, axis=1) #열 a,b,c,d 삭제
df.drop(cols, axis=1, inplace=True)

#결측치 대체
df.replace('변경전', '변경후', inplace=True)
df.replcae({'전':'후', '전1':'후1'}, inplace=True)

#결측치 채우기
df.fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None)
df.fillna('A') #결측치를 a로 채우기
df.fillna(value={'col1':'A', 'col2':'B'})
#col1의 모든 결측값을 a로 대체
#col2의 모든 결측값을 b로 대체
df.fillna(method='bfill')

#데이터 타입에 따른 칼럼명
obj = df.select_dtypes('object').columns
#object 타입의 열만 선택
obj_x = df.select_dtypes(exclude='object').columns
#object 아닌 열들만 선택

#라벨 인코딩
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['c'] = le.fit_transform(df['c'])

#원핫 인코딩
from sklearn.preprocessing import OneHotEncoder
oh = OneHotEncder()
df['c'] - oh.fit_transform(df['c'])
#get_dummies 활용한 원핫 인코딩
cols = ['__', '___']
df1 = pd.get_dummies(df, columns=cols)

#그래프
sns.histplot(x='__', hue='__', data=df)
sns.kdeplot(df['a'])
sns.countplot(x='__', data=df)
df['a'].value_counts().plot(kind='bar')
sns.boxplot(x='_', y='_', data=df)
#히트맵
heat=df[['a', 'b','c']].corr()
sns.heatmap(heat, annot=True, cmap='Blues')

#X,Y로 데이터 분리하기
df = pd.read_csv('__.csv')
x_data = df.drop('___', axis=1).values
y_data = df1['__'].values

#X,y, train,test 데이터 분리하기
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, stratify=y_data, random_state=42)

#데이터 표준화/정규화
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

#머신러닝 모델링. 분류 라이브러리 & 모델 선언
from sklearn.linear_model import LogisticRegression
lg = LogisticRegression()
model = lg( ~~)

#이런식으로
from sklearn.neighbors import KNeighborsClassifier
knc = KNeighborsClassifier()
DecisionTreeClassifier
RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

#분류 모델학습
lr.fit(x_train, y_train)

#분류 성능평가
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
y_pred = lr.predict(x_test)

print(accuracy_score(y_test, y_pred))
print(recall_score(y_test, y_pred))
print(precision_score(y_test, y_pred))

#분류 히트맵
heat = confusion_matrix(y_test, y_pred)
sns.heatmap(heat, annot=True, fmt='d', color='Blues')
#회귀도 그래도 진행. Regressor

#분류, 회귀 구분하기

#딥러닝 모델
#input_shape는 x_train 모양이랑 같게.
#x_train.shape 통해서 확인후 직접 입력
model = Sequential()
model.add(Dense(4, activation='relu', input_shape=(xx, )))
#주어진 모델대로 입력.
#마지막에 이진 분류 하라고하면
model.add(Dense(1, activation='sigmoid'))

es = EarlyStopping(monitor ='val_loss', patience=0, mode='min,verbose=1')
mc = ModelCheckpoint(~~)

#모델 컴파일
model.compile(optimizer='adam', loss='binary_crossentropy')
#이진분류일때는 metrics = ['accuracy']
#회귀는 loss='mse'

history = model.fit(x_train, y_train, epochs=_, batch_size=_, 
                    validation_data=(x_test, y_test), callbacks=[es,mc],
                    verbose=True).history

plt.plot(history['loss'], label='Train_loss')
plt.plot(history['val_loss'], label='Validation_loss')
plt.xlabel('__')
plt.ylabel('___')
plt.legend()
plt.show()
